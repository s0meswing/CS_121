# %% [markdown]
# Lior Wilensky;
# CS 121 Python DS and ML;
# 15th Feb, 2026;
# Lab 1: Installing Jupyter Notebooks/Anaconda

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# Reflection:
# 1. To run the code, I pressed ctrl + alt + enter at the same time. Alternatively, I could have clicked the triangle on the left hand side of the code cell. For the markdown cells, I pressed the triangle on the upper right hand side, though it didn't do much of anything.
# 2. This is more visually cluttered yet also modular than a .py file, as more lines of code can be ran independently of each other. However, this comes at the expense of needing visual cells and more execution buttons.
# 3. I am using the Microsoft pre-release of "Jupyter Notebook Renderer" as it came pre-installed as a package when downloading J upyter via VS Code Extensions.
